# %%
import json

def refine_cluster_mapping(mapping_file='cluster_mapping.json', keep_prefixes=None, output_file=None):
    """
    cluster_mapping.json 파일의 내용을 정제하여 KEEP_PREFIXES에 있는 필드만 추출하고
    각 클러스터별로 정리해서 보여주는 함수
    
    Args:
        mapping_file: cluster_mapping.json 파일 경로
        keep_prefixes: 유지할 필드 접두사 튜플 (None이면 기본값 사용)
        output_file: 정제된 결과를 저장할 파일 경로 (None이면 저장하지 않음)
    
    Returns:
        정제된 클러스터 매핑 딕셔너리
    """
    # keep_prefixes 설정
    if keep_prefixes is None:
        keep_prefixes = ('processName', 'eventName', 'syscall', 'args', 'executable', 'returnValue')
    
    # cluster_mapping.json 파일 읽기
    with open(mapping_file, 'r', encoding='utf-8') as f:
        mapping = json.load(f)
    
    # 정제된 결과 저장용
    refined_mapping = {
        'total_clusters': mapping.get('total_clusters', 0),
        'total_samples': mapping.get('total_samples', 0),
        'keep_prefixes': list(keep_prefixes),
        'clusters': {}
    }
    
    # 각 클러스터별로 정제
    for cluster_id, cluster_info in mapping.get('clusters', {}).items():
        refined_cluster = {
            'cluster_id': int(cluster_id) if cluster_id != '-1' else -1,
            'count': cluster_info.get('count', 0),
            'data': []
        }
        
        # 각 데이터 항목에서 KEEP_PREFIXES에 해당하는 필드만 추출
        for item in cluster_info.get('data', []):
            original_data = item.get('data', {})
            refined_data = {
                'index': item.get('index'),
                'filtered_data': {}
            }
            
            # 원본 데이터가 딕셔너리인 경우
            if isinstance(original_data, dict):
                for key, value in original_data.items():
                    # keep_prefixes에 해당하는 키만 추출
                    if any(key.startswith(prefix) for prefix in keep_prefixes):
                        refined_data['filtered_data'][key] = value
            else:
                # 딕셔너리가 아닌 경우 그대로 저장
                refined_data['filtered_data'] = original_data
            
            refined_cluster['data'].append(refined_data)
        
        # 클러스터별 통계 정보 추가
        if refined_cluster['data']:
            # 첫 번째 샘플 데이터
            first_sample = refined_cluster['data'][0].get('filtered_data', {})
            refined_cluster['sample_data'] = first_sample
            
            # 주요 필드별 통계
            process_names = []
            event_names = []
            syscalls = []
            
            for item in refined_cluster['data']:
                filtered = item.get('filtered_data', {})
                if isinstance(filtered, dict):
                    if 'processName' in filtered:
                        process_names.append(filtered['processName'])
                    if 'eventName' in filtered:
                        event_names.append(filtered['eventName'])
                    if 'syscall' in filtered:
                        syscalls.append(filtered['syscall'])
            
            refined_cluster['statistics'] = {
                'unique_processes': len(set(process_names)) if process_names else 0,
                'unique_events': len(set(event_names)) if event_names else 0,
                'unique_syscalls': len(set(syscalls)) if syscalls else 0,
                'most_common_process': max(set(process_names), key=process_names.count) if process_names else None,
                'most_common_event': max(set(event_names), key=event_names.count) if event_names else None,
                'most_common_syscall': max(set(syscalls), key=syscalls.count) if syscalls else None,
            }
        
        refined_mapping['clusters'][cluster_id] = refined_cluster
    
    # 결과 출력
    print("=" * 80)
    print("정제된 클러스터 매핑 정보")
    print("=" * 80)
    print(f"총 클러스터 수: {refined_mapping['total_clusters']}")
    print(f"총 샘플 수: {refined_mapping['total_samples']}")
    print(f"유지된 필드 접두사: {refined_mapping['keep_prefixes']}")
    print()
    
    # 클러스터별 요약 출력 (크기 순으로 정렬)
    sorted_clusters = sorted(
        refined_mapping['clusters'].items(),
        key=lambda x: x[1]['count'],
        reverse=True
    )
    
    print("클러스터별 요약:")
    print("-" * 80)
    for cluster_id, cluster_info in sorted_clusters:
        stats = cluster_info.get('statistics', {})
        print(f"\n[클러스터 {cluster_id}] 데이터 개수: {cluster_info['count']}")
        if stats:
            print(f"  - 고유 프로세스 수: {stats['unique_processes']}")
            print(f"  - 고유 이벤트 수: {stats['unique_events']}")
            print(f"  - 고유 시스템콜 수: {stats['unique_syscalls']}")
            if stats['most_common_process']:
                print(f"  - 가장 흔한 프로세스: {stats['most_common_process']}")
            if stats['most_common_event']:
                print(f"  - 가장 흔한 이벤트: {stats['most_common_event']}")
            if stats['most_common_syscall']:
                print(f"  - 가장 흔한 시스템콜: {stats['most_common_syscall']}")
        
        # 샘플 데이터 출력
        sample = cluster_info.get('sample_data', {})
        if sample:
            print(f"  - 샘플 데이터: {sample}")
    
    # 파일로 저장 (옵션)
    if output_file:
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(refined_mapping, f, ensure_ascii=False, indent=2)
        print(f"\n정제된 결과가 {output_file}에 저장되었습니다.")
    
    return refined_mapping

# 사용 예시
# refined = refine_cluster_mapping(
#     mapping_file='cluster_mapping.json',
#     output_file='cluster_mapping_refined.json'  # 선택사항: 저장하지 않으려면 None
# )

# %%
import pandas as pd
import json

def refined_json_to_dataframe(json_file='cluster_mapping_refined.json'):
    """
    cluster_mapping_refined.json 파일을 읽어서 데이터프레임으로 변환하는 함수
    
    Args:
        json_file: cluster_mapping_refined.json 파일 경로
    
    Returns:
        pandas DataFrame: 각 행이 하나의 샘플 데이터를 나타냄
                         컬럼: cluster_id, index, 그리고 filtered_data의 모든 필드
    """
    # JSON 파일 읽기
    with open(json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    # 모든 샘플 데이터를 저장할 리스트
    rows = []
    
    # 각 클러스터별로 데이터 추출
    for cluster_id, cluster_info in data.get('clusters', {}).items():
        cluster_id_int = cluster_info.get('cluster_id', int(cluster_id) if cluster_id != '-1' else -1)
        
        # 각 데이터 항목을 행으로 변환
        for item in cluster_info.get('data', []):
            row = {
                'cluster_id': cluster_id_int,
                'index': item.get('index')
            }
            
            # filtered_data의 모든 필드를 행에 추가
            filtered_data = item.get('filtered_data', {})
            if isinstance(filtered_data, dict):
                for key, value in filtered_data.items():
                    # 중첩된 객체(예: args, executable)는 JSON 문자열로 변환
                    if isinstance(value, (dict, list)):
                        row[key] = json.dumps(value, ensure_ascii=False)
                    else:
                        row[key] = value
            else:
                row['filtered_data'] = filtered_data
            
            rows.append(row)
    
    # DataFrame 생성
    df = pd.DataFrame(rows)
    
    # 컬럼 순서 정리 (cluster_id, index를 앞에 배치)
    if not df.empty:
        cols = ['cluster_id', 'index']
        other_cols = [c for c in df.columns if c not in cols]
        df = df[cols + other_cols]
    
    return df

# 사용 예시
# df = refined_json_to_dataframe('cluster_mapping_refined.json')
# print(df.head())
# print(f"\n데이터프레임 shape: {df.shape}")
# print(f"\n컬럼: {df.columns.tolist()}")

# %%
# 사용 예시
refined = refine_cluster_mapping(
     mapping_file='cluster_mapping.json',
     output_file ='cluster_mapping_refined.json')  # 선택사항: 저장하지 않으려면 None
# Out:
# ================================================================================
# 정제된 클러스터 매핑 정보
# ================================================================================
# 총 클러스터 수: 8
# 총 샘플 수: 721
# 유지된 필드 접두사: ['processName', 'eventName', 'syscall', 'args', 'executable', 'returnValue']
#
# 클러스터별 요약:
# --------------------------------------------------------------------------------
#
# [클러스터 5] 데이터 개수: 258
#   - 고유 프로세스 수: 1
#   - 고유 이벤트 수: 1
#   - 고유 시스템콜 수: 1
#   - 가장 흔한 프로세스: init
#   - 가장 흔한 이벤트: setresgid
#   - 가장 흔한 시스템콜: setresgid
#   - 샘플 데이터: {'processName': 'init', 'executable': {'path': ''}, 'eventName': 'setresgid', 'argsNum': 3, 'returnValue': 0, 'syscall': 'setresgid', 'args': [{'name': 'rgid', 'type': 'int32', 'value': -1}, {'name': 'egid', 'type': 'int32', 'value': 1000}, {'name': 'sgid', 'type': 'int32', 'value': -1}]}
#
# [클러스터 6] 데이터 개수: 258
#   - 고유 프로세스 수: 1
#   - 고유 이벤트 수: 1
#   - 고유 시스템콜 수: 1
#   - 가장 흔한 프로세스: init
#   - 가장 흔한 이벤트: setresuid
#   - 가장 흔한 시스템콜: setresuid
#   - 샘플 데이터: {'processName': 'init', 'executable': {'path': ''}, 'eventName': 'setresuid', 'argsNum': 3, 'returnValue': 0, 'syscall': 'setresuid', 'args': [{'name': 'ruid', 'type': 'int32', 'value': -1}, {'name': 'euid', 'type': 'int32', 'value': 1000}, {'name': 'suid', 'type': 'int32', 'value': -1}]}
#
# [클러스터 0] 데이터 개수: 62
#   - 고유 프로세스 수: 1
#   - 고유 이벤트 수: 1
#   - 고유 시스템콜 수: 1
#   - 가장 흔한 프로세스: initd
#   - 가장 흔한 이벤트: security_socket_connect
#   - 가장 흔한 시스템콜: connect
#   - 샘플 데이터: {'processName': 'initd', 'executable': {'path': ''}, 'eventName': 'security_socket_connect', 'argsNum': 3, 'returnValue': 0, 'syscall': 'connect', 'args': [{'name': 'sockfd', 'type': 'int32', 'value': 178}, {'name': 'type', 'type': 'int32', 'value': 1}, {'name': 'remote_addr', 'type': 'SockAddr', 'value': {'sa_family': 'AF_UNIX', 'sun_path': '/run/guest-services/stats.sock'}}]}
#
# [클러스터 2] 데이터 개수: 53
#   - 고유 프로세스 수: 1
#   - 고유 이벤트 수: 1
#   - 고유 시스템콜 수: 1
#   - 가장 흔한 프로세스: bash
#   - 가장 흔한 이벤트: setpgid
#   - 가장 흔한 시스템콜: setpgid
#   - 샘플 데이터: {'processName': 'bash', 'executable': {'path': ''}, 'eventName': 'setpgid', 'argsNum': 2, 'returnValue': 0, 'syscall': 'setpgid', 'args': [{'name': 'pid', 'type': 'int32', 'value': 1086}, {'name': 'pgid', 'type': 'int32', 'value': 1086}]}
#
# [클러스터 4] 데이터 개수: 36
#   - 고유 프로세스 수: 1
#   - 고유 이벤트 수: 1
#   - 고유 시스템콜 수: 1
#   - 가장 흔한 프로세스: ls
#   - 가장 흔한 이벤트: security_socket_connect
#   - 가장 흔한 시스템콜: connect
#   - 샘플 데이터: {'processName': 'ls', 'executable': {'path': ''}, 'eventName': 'security_socket_connect', 'argsNum': 3, 'returnValue': 0, 'syscall': 'connect', 'args': [{'name': 'sockfd', 'type': 'int32', 'value': 4}, {'name': 'type', 'type': 'int32', 'value': 1}, {'name': 'remote_addr', 'type': 'SockAddr', 'value': {'sa_family': 'AF_UNIX', 'sun_path': '/var/run/nscd/socket'}}]}
#
# [클러스터 -1] 데이터 개수: 23
#   - 고유 프로세스 수: 11
#   - 고유 이벤트 수: 7
#   - 고유 시스템콜 수: 6
#   - 가장 흔한 프로세스: init
#   - 가장 흔한 이벤트: security_socket_connect
#   - 가장 흔한 시스템콜: connect
#   - 샘플 데이터: {'processName': 'tracee', 'executable': {'path': ''}, 'eventName': 'security_socket_connect', 'argsNum': 3, 'returnValue': 0, 'syscall': 'connect', 'args': [{'name': 'sockfd', 'type': 'int32', 'value': 393}, {'name': 'type', 'type': 'int32', 'value': 1}, {'name': 'remote_addr', 'type': 'SockAddr', 'value': {'sa_family': 'AF_UNIX', 'sun_path': '/var/run/docker.sock'}}]}
#
# [클러스터 1] 데이터 개수: 16
#   - 고유 프로세스 수: 1
#   - 고유 이벤트 수: 1
#   - 고유 시스템콜 수: 1
#   - 가장 흔한 프로세스: docker-desktop-
#   - 가장 흔한 이벤트: security_socket_connect
#   - 가장 흔한 시스템콜: connect
#   - 샘플 데이터: {'processName': 'docker-desktop-', 'executable': {'path': ''}, 'eventName': 'security_socket_connect', 'argsNum': 3, 'returnValue': 0, 'syscall': 'connect', 'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21}, {'name': 'type', 'type': 'int32', 'value': 1}, {'name': 'remote_addr', 'type': 'SockAddr', 'value': {'sa_family': 'AF_UNIX', 'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}
#
# [클러스터 3] 데이터 개수: 15
#   - 고유 프로세스 수: 1
#   - 고유 이벤트 수: 1
#   - 고유 시스템콜 수: 1
#   - 가장 흔한 프로세스: ls
#   - 가장 흔한 이벤트: sched_process_exec
#   - 가장 흔한 시스템콜: execve
#   - 샘플 데이터: {'processName': 'ls', 'executable': {'path': ''}, 'eventName': 'sched_process_exec', 'argsNum': 17, 'returnValue': 0, 'syscall': 'execve', 'args': [{'name': 'cmdpath', 'type': 'string', 'value': '/usr/bin/ls'}, {'name': 'pathname', 'type': 'string', 'value': '/usr/bin/ls'}, {'name': 'dev', 'type': 'uint32', 'value': 8388656}, {'name': 'inode', 'type': 'uint64', 'value': 1793}, {'name': 'ctime', 'type': 'uint64', 'value': 1770355888840991152}, {'name': 'inode_mode', 'type': 'uint16', 'value': 33261}, {'name': 'interpreter_pathname', 'type': 'string', 'value': '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'}, {'name': 'interpreter_dev', 'type': 'uint32', 'value': 8388656}, {'name': 'interpreter_inode', 'type': 'uint64', 'value': 11429}, {'name': 'interpreter_ctime', 'type': 'uint64', 'value': 1770355894092991029}, {'name': 'argv', 'type': '[]string', 'value': ['ls', '--color=auto']}, {'name': 'interp', 'type': 'string', 'value': '/usr/bin/ls'}, {'name': 'stdin_type', 'type': 'uint16', 'value': 8192}, {'name': 'stdin_path', 'type': 'string', 'value': '/dev/pts/7'}, {'name': 'invoked_from_kernel', 'type': 'bool', 'value': False}, {'name': 'prev_comm', 'type': 'string', 'value': 'bash'}, {'name': 'env', 'type': '[]string', 'value': []}, {'name': 'pwd', 'type': 'string', 'value': '/root'}]}
#
# 정제된 결과가 cluster_mapping_refined.json에 저장되었습니다.

# %%
df = refined_json_to_dataframe('cluster_mapping_refined.json')
print(df.head())
print(f"\n데이터프레임 shape: {df.shape}")
print(f"\n컬럼: {df.columns.tolist()}")
# Out:
#    cluster_id  index processName    executable                eventName  \
# 0           0      0       initd  {"path": ""}  security_socket_connect
# 1           0      5       initd  {"path": ""}  security_socket_connect
# 2           0     10       initd  {"path": ""}  security_socket_connect
# 3           0     15       initd  {"path": ""}  security_socket_connect
# 4           0     18       initd  {"path": ""}  security_socket_connect
#
#    argsNum  returnValue  syscall  \
# 0        3            0  connect
# 1        3            0  connect
# 2        3            0  connect
# 3        3            0  connect
# 4        3            0  connect
#
#                                                 args
# 0  [{"name": "sockfd", "type": "int32", "value": ...
# 1  [{"name": "sockfd", "type": "int32", "value": ...
# 2  [{"name": "sockfd", "type": "int32", "value": ...
# 3  [{"name": "sockfd", "type": "int32", "value": ...
# 4  [{"name": "sockfd", "type": "int32", "value": ...
#
# 데이터프레임 shape: (721, 9)
#
# 컬럼: ['cluster_id', 'index', 'processName', 'executable', 'eventName', 'argsNum', 'returnValue', 'syscall', 'args']

# %%
import numpy as np

def match_sequence_with_clusters(original_sequence, cluster_labels):
    """
    원본 시퀀스와 클러스터링 결과를 매칭하여 각 항목에 클러스터 ID를 추가하는 함수
    
    Args:
        original_sequence: 원본 데이터 시퀀스 (리스트 또는 배열)
                          - 리스트: [data1, data2, data3, ...]
                          - DataLoader의 dataset.original_data
                          - 또는 다른 순서가 보장된 시퀀스
        cluster_labels: 클러스터링 결과 레이블 (numpy array 또는 리스트)
                       - 길이는 original_sequence와 동일해야 함
                       - 각 값은 해당 인덱스의 클러스터 ID
    
    Returns:
        list: 각 항목이 {'data': 원본데이터, 'cluster_id': 클러스터ID, 'index': 인덱스} 형태인 리스트
    """
    # 입력 검증
    if len(original_sequence) != len(cluster_labels):
        raise ValueError(
            f"원본 시퀀스 길이({len(original_sequence)})와 클러스터 레이블 길이({len(cluster_labels)})가 일치하지 않습니다."
        )
    
    # cluster_labels를 numpy array로 변환 (리스트인 경우 대비)
    if not isinstance(cluster_labels, np.ndarray):
        cluster_labels = np.array(cluster_labels)
    
    # 매칭된 결과 리스트 생성
    matched_sequence = []
    
    for idx, (data, cluster_id) in enumerate(zip(original_sequence, cluster_labels)):
        matched_item = {
            'index': idx,
            'cluster_id': int(cluster_id),
            'data': data
        }
        matched_sequence.append(matched_item)
    
    return matched_sequence

# 사용 예시
# # 예시 1: 리스트 형태의 원본 데이터
# original_data = [{'processName': 'init'}, {'processName': 'bash'}, {'processName': 'ls'}]
# labels = np.array([0, 1, 0])
# matched = match_sequence_with_clusters(original_data, labels)
# print("매칭 결과:")
# for item in matched:
#     print(f"  인덱스 {item['index']}: 클러스터 {item['cluster_id']}, 데이터: {item['data']}")
# 
# # 예시 2: DataLoader의 original_data 사용
# # matched = match_sequence_with_clusters(train_normal_loader.dataset.original_data, labels)

# %%
# match_sequence_with_clusters 함수 실행 구조
import os

def load_original_sequence_from_file(data_file='data/tr_normal_tracee.json'):
    """
    원본 JSON Lines 파일에서 원본 시퀀스를 로드하는 함수
    
    Args:
        data_file: 원본 데이터 파일 경로
    
    Returns:
        list: 원본 데이터 시퀀스
    """
    original_sequence = []
    
    if not os.path.exists(data_file):
        raise FileNotFoundError(f"데이터 파일을 찾을 수 없습니다: {data_file}")
    
    with open(data_file, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                try:
                    json_obj = json.loads(line)
                    original_sequence.append(json_obj)
                except json.JSONDecodeError:
                    continue
    
    return original_sequence

def load_cluster_labels_from_mapping(mapping_file='cluster_mapping.json', convert_noise_to_cluster=True):
    """
    cluster_mapping.json에서 클러스터 레이블을 재구성하는 함수
    
    Args:
        mapping_file: cluster_mapping.json 파일 경로
        convert_noise_to_cluster: True이면 노이즈(-1)를 별도의 클러스터 ID로 변환
    
    Returns:
        numpy array: 인덱스 순서대로 정렬된 클러스터 레이블
    """
    with open(mapping_file, 'r', encoding='utf-8') as f:
        mapping = json.load(f)
    
    # 인덱스와 클러스터 ID 매핑 딕셔너리 생성
    index_to_cluster = {}
    cluster_ids_set = set()
    
    for cluster_id, cluster_info in mapping.get('clusters', {}).items():
        cluster_id_int = int(cluster_id) if cluster_id != '-1' else -1
        
        for item in cluster_info.get('data', []):
            idx = item.get('index')
            if idx is not None:
                index_to_cluster[idx] = cluster_id_int
                if cluster_id_int != -1:
                    cluster_ids_set.add(cluster_id_int)
    
    # 최대 인덱스 찾기
    if not index_to_cluster:
        raise ValueError("클러스터 매핑에 데이터가 없습니다.")
    
    max_index = max(index_to_cluster.keys())
    
    # 노이즈를 별도 클러스터 ID로 변환
    if convert_noise_to_cluster:
        # 기존 클러스터 ID 중 최대값 찾기
        if cluster_ids_set:
            max_cluster_id = max(cluster_ids_set)
            next_cluster_id = max_cluster_id + 1
        else:
            next_cluster_id = 0
        
        # 노이즈 포인트를 개별 클러스터로 변환 (각각 다른 ID 부여)
        noise_indices = [idx for idx, cid in index_to_cluster.items() if cid == -1]
        noise_count = len(noise_indices)
        
        if noise_count > 0:
            # 각 노이즈 포인트에 고유한 클러스터 ID 부여
            for i, idx in enumerate(noise_indices):
                index_to_cluster[idx] = next_cluster_id + i
            
            if noise_count == 1:
                print(f"   노이즈 포인트(-1) 1개를 클러스터 ID {next_cluster_id}로 변환했습니다.")
            else:
                print(f"   노이즈 포인트(-1) {noise_count}개를 클러스터 ID {next_cluster_id}~{next_cluster_id + noise_count - 1}로 변환했습니다.")
        else:
            print("   노이즈 포인트가 없습니다.")
    
    # 인덱스 순서대로 클러스터 레이블 배열 생성
    cluster_labels = np.zeros(max_index + 1, dtype=int)
    
    for idx, cluster_id in index_to_cluster.items():
        cluster_labels[idx] = cluster_id
    
    return cluster_labels

# %%
# matched_sequence를 파일로 저장
def save_matched_sequence(matched_sequence, output_file='matched_sequence.json'):
    """
    matched_sequence를 JSON 파일로 저장하는 함수
    
    Args:
        matched_sequence: match_sequence_with_clusters 함수의 결과
        output_file: 저장할 파일 경로
    """
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(matched_sequence, f, ensure_ascii=False, indent=2)
    
    print(f"matched_sequence가 {output_file}에 저장되었습니다.")
    print(f"총 {len(matched_sequence)}개의 항목이 저장되었습니다.")

# matched_sequence가 존재하는 경우 저장
if 'matched_sequence' in globals() and matched_sequence:
    save_matched_sequence(matched_sequence, 'matched_sequence.json')
else:
    print("matched_sequence 변수가 없습니다. 먼저 셀 5를 실행해주세요.")
# Out:
# matched_sequence 변수가 없습니다. 먼저 셀 5를 실행해주세요.

# %%
# 실행 구조
print("=" * 80)
print("원본 시퀀스와 클러스터 매칭 실행")
print("=" * 80)

# 1. 원본 데이터 시퀀스 로드
print("\n1. 원본 데이터 시퀀스 로드 중...")
original_sequence = load_original_sequence_from_file('data/tr_normal_tracee.json')
print(f"   로드된 데이터 개수: {len(original_sequence)}")

# 2. 클러스터 레이블 로드
print("\n2. 클러스터 레이블 로드 중...")
cluster_labels = load_cluster_labels_from_mapping('cluster_mapping.json')
print(f"   클러스터 레이블 개수: {len(cluster_labels)}")
print(f"   고유 클러스터 수: {len(set(cluster_labels))}")

# 3. 길이 확인 및 조정 (필요한 경우)
print("\n3. 데이터 길이 확인...")
if len(original_sequence) != len(cluster_labels):
    min_len = min(len(original_sequence), len(cluster_labels))
    print(f"   경고: 길이가 다릅니다. 원본: {len(original_sequence)}, 레이블: {len(cluster_labels)}")
    print(f"   최소 길이({min_len})로 조정합니다.")
    original_sequence = original_sequence[:min_len]
    cluster_labels = cluster_labels[:min_len]

# 4. match_sequence_with_clusters 함수 실행
print("\n4. 시퀀스와 클러스터 매칭 중...")
matched_sequence = match_sequence_with_clusters(original_sequence, cluster_labels)
print(f"   매칭 완료! 총 {len(matched_sequence)}개 항목")

# 5. 결과 확인
print("\n5. 매칭 결과 샘플 (처음 5개):")
print("-" * 80)
for i, item in enumerate(matched_sequence[:5]):
    data = item['data']
    process_name = data.get('processName', 'N/A')
    event_name = data.get('eventName', 'N/A')
    print(f"  인덱스 {item['index']:3d}: 클러스터 {item['cluster_id']:2d} | "
          f"프로세스: {process_name:15s} | 이벤트: {event_name}")

# 6. 클러스터별 통계
print("\n6. 클러스터별 데이터 개수:")
print("-" * 80)
from collections import Counter
cluster_counts = Counter([item['cluster_id'] for item in matched_sequence])
for cluster_id, count in sorted(cluster_counts.items()):
    print(f"  클러스터 {cluster_id:2d}: {count:4d}개")

print("\n" + "=" * 80)
print("매칭 완료!")
print("=" * 80)
print(f"\nmatched_sequence 변수에 결과가 저장되었습니다.")
print(f"총 {len(matched_sequence)}개의 매칭된 항목이 있습니다.")
# Out:
# ================================================================================
# 원본 시퀀스와 클러스터 매칭 실행
# ================================================================================
#
# 1. 원본 데이터 시퀀스 로드 중...
#    로드된 데이터 개수: 721
#
# 2. 클러스터 레이블 로드 중...
#    노이즈 포인트(-1) 23개를 클러스터 ID 7~29로 변환했습니다.
#    클러스터 레이블 개수: 721
#    고유 클러스터 수: 30
#
# 3. 데이터 길이 확인...
#
# 4. 시퀀스와 클러스터 매칭 중...
#    매칭 완료! 총 721개 항목
#
# 5. 매칭 결과 샘플 (처음 5개):
# --------------------------------------------------------------------------------
#   인덱스   0: 클러스터  0 | 프로세스: initd           | 이벤트: security_socket_connect
#   인덱스   1: 클러스터  7 | 프로세스: tracee          | 이벤트: security_socket_connect
#   인덱스   2: 클러스터  1 | 프로세스: docker-desktop- | 이벤트: security_socket_connect
#   인덱스   3: 클러스터  1 | 프로세스: docker-desktop- | 이벤트: security_socket_connect
#   인덱스   4: 클러스터  1 | 프로세스: docker-desktop- | 이벤트: security_socket_connect
#
# 6. 클러스터별 데이터 개수:
# --------------------------------------------------------------------------------
#   클러스터  0:   62개
#   클러스터  1:   16개
#   클러스터  2:   53개
#   클러스터  3:   15개
#   클러스터  4:   36개
#   클러스터  5:  258개
#   클러스터  6:  258개
#   클러스터  7:    1개
#   클러스터  8:    1개
#   클러스터  9:    1개
#   클러스터 10:    1개
#   클러스터 11:    1개
#   클러스터 12:    1개
#   클러스터 13:    1개
#   클러스터 14:    1개
#   클러스터 15:    1개
#   클러스터 16:    1개
#   클러스터 17:    1개
#   클러스터 18:    1개
#   클러스터 19:    1개
#   클러스터 20:    1개
#   클러스터 21:    1개
#   클러스터 22:    1개
#   클러스터 23:    1개
#   클러스터 24:    1개
#   클러스터 25:    1개
#   클러스터 26:    1개
#   클러스터 27:    1개
#   클러스터 28:    1개
#   클러스터 29:    1개
#
# ================================================================================
# 매칭 완료!
# ================================================================================
#
# matched_sequence 변수에 결과가 저장되었습니다.
# 총 721개의 매칭된 항목이 있습니다.

# %%
matched_sequence
# Out:
# [{'index': 0,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361145686246159,
#    'threadStartTime': 1770357810525966063,
#    'processorId': 9,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 365,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 2164,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1496401534,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 178},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/run/guest-services/stats.sock'}}]}},
#  {'index': 1,
#   'cluster_id': 7,
#   'data': {'timestamp': 1770361145837665844,
#    'threadStartTime': 1770361143499520647,
#    'processorId': 5,
#    'processId': 800,
#    'cgroupId': 3488,
#    'threadId': 803,
#    'parentProcessId': 786,
#    'hostProcessId': 2882,
#    'hostThreadId': 2885,
#    'hostParentProcessId': 2868,
#    'userId': 0,
#    'mountNamespace': 4026532315,
#    'pidNamespace': 4026532391,
#    'processName': 'tracee',
#    'executable': {'path': ''},
#    'hostName': '6e299da3f233',
#    'containerId': '6e299da3f233b5254d582293312a8999470f164e3933c4ea2b56b4a622e2616a',
#    'container': {'id': '6e299da3f233b5254d582293312a8999470f164e3933c4ea2b56b4a622e2616a',
#     'name': 'tracee_1',
#     'image': 'aquasec/tracee:latest',
#     'imageDigest': 'aquasec/tracee@sha256:cfbbfee972e64a644f6b1bac74ee26998e6e12442697be4c797ae563553a2a5b'},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': True, 'isCompat': False},
#    'threadEntityId': 478529230,
#    'processEntityId': 2693343887,
#    'parentEntityId': 1159042132,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 393},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX', 'sun_path': '/var/run/docker.sock'}}]}},
#  {'index': 2,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145838839570,
#    'threadStartTime': 1770357444963927576,
#    'processorId': 12,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 798,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2073,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3442353639,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 3,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145841368018,
#    'threadStartTime': 1770357444969382056,
#    'processorId': 6,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 801,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2076,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 43146251,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 4,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145845710829,
#    'threadStartTime': 1770357444918185943,
#    'processorId': 10,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 796,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2071,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 428122265,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/guest-services/docker.proxy.sock'}}]}},
#  {'index': 5,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361145846198606,
#    'threadStartTime': 1770357810525966063,
#    'processorId': 12,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 365,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 2164,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1496401534,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 200},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/var/run/docker.raw.sock'}}]}},
#  {'index': 6,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145847737838,
#    'threadStartTime': 1770357444969382056,
#    'processorId': 6,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 801,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2076,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 43146251,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 7,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145850720676,
#    'threadStartTime': 1770357444964082790,
#    'processorId': 7,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 799,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2074,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1048328759,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 8,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145852813054,
#    'threadStartTime': 1770357444964082790,
#    'processorId': 7,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 799,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2074,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1048328759,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 9,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145855624625,
#    'threadStartTime': 1770357444918185943,
#    'processorId': 10,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 796,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2071,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 428122265,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/guest-services/docker.proxy.sock'}}]}},
#  {'index': 10,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361145856127453,
#    'threadStartTime': 1770357441751507167,
#    'processorId': 15,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 69,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1703,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3613075782,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 190},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/var/run/docker.raw.sock'}}]}},
#  {'index': 11,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145860083439,
#    'threadStartTime': 1770357444969382056,
#    'processorId': 6,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 801,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2076,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 43146251,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 12,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145863744372,
#    'threadStartTime': 1770357444964082790,
#    'processorId': 7,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 799,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2074,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1048328759,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 13,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145866833193,
#    'threadStartTime': 1770357444964082790,
#    'processorId': 10,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 799,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2074,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1048328759,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 14,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145869256436,
#    'threadStartTime': 1770357444918185943,
#    'processorId': 3,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 796,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2071,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 428122265,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/guest-services/docker.proxy.sock'}}]}},
#  {'index': 15,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361145869820917,
#    'threadStartTime': 1770357441741263008,
#    'processorId': 14,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 56,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1690,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1635754555,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 190},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/var/run/docker.raw.sock'}}]}},
#  {'index': 16,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145912806485,
#    'threadStartTime': 1770357444963927576,
#    'processorId': 4,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 798,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2073,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3442353639,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 17,
#   'cluster_id': 8,
#   'data': {'timestamp': 1770361145837665844,
#    'threadStartTime': 1770361143499520647,
#    'processorId': 5,
#    'processId': 800,
#    'cgroupId': 3488,
#    'threadId': 803,
#    'parentProcessId': 786,
#    'hostProcessId': 2882,
#    'hostThreadId': 2885,
#    'hostParentProcessId': 2868,
#    'userId': 0,
#    'mountNamespace': 4026532315,
#    'pidNamespace': 4026532391,
#    'processName': 'tracee',
#    'executable': {'path': ''},
#    'hostName': '6e299da3f233',
#    'containerId': '6e299da3f233b5254d582293312a8999470f164e3933c4ea2b56b4a622e2616a',
#    'container': {'id': '6e299da3f233b5254d582293312a8999470f164e3933c4ea2b56b4a622e2616a',
#     'name': 'tracee_1',
#     'image': 'aquasec/tracee:latest',
#     'imageDigest': 'aquasec/tracee@sha256:cfbbfee972e64a644f6b1bac74ee26998e6e12442697be4c797ae563553a2a5b'},
#    'kubernetes': {},
#    'eventId': '6004',
#    'eventName': 'docker_abuse',
#    'matchedPolicies': [''],
#    'argsNum': 1,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': True, 'isCompat': False},
#    'threadEntityId': 478529230,
#    'processEntityId': 2693343887,
#    'parentEntityId': 1159042132,
#    'args': [{'name': 'detectedFrom',
#      'type': 'unknown',
#      'value': {'args': [{'name': 'sockfd', 'type': 'int32', 'value': 393},
#        {'name': 'type', 'type': 'int32', 'value': 1},
#        {'name': 'remote_addr',
#         'type': 'SockAddr',
#         'value': {'sa_family': 'AF_UNIX',
#          'sun_path': '/var/run/docker.sock'}}],
#       'id': 736,
#       'name': 'security_socket_connect',
#       'returnValue': 0}}],
#    'metadata': {'Version': '1',
#     'Description': 'An attempt to abuse the Docker UNIX socket inside a container was detected. docker.sock is the UNIX socket that Docker uses as the entry point to the Docker API. Adversaries may attempt to abuse this socket to compromise the system.',
#     'Tags': None,
#     'Properties': {'Category': 'privilege-escalation',
#      'Kubernetes_Technique': '',
#      'Severity': 2,
#      'Technique': 'Exploitation for Privilege Escalation',
#      'external_id': 'T1068',
#      'id': 'attack-pattern--b21c3b2d-02e6-45b1-980b-e69051040839',
#      'signatureID': 'TRC-1019',
#      'signatureName': 'Docker socket abuse detected'}}}},
#  {'index': 18,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361150270108776,
#    'threadStartTime': 1770357441751507167,
#    'processorId': 13,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 69,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1703,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3613075782,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 178},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/run/guest-services/stats.sock'}}]}},
#  {'index': 19,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361152752993617,
#    'threadStartTime': 1770357441750829188,
#    'processorId': 10,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 67,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1701,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1762651660,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 178},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/var/run/docker.raw.sock'}}]}},
#  {'index': 20,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361152757078372,
#    'threadStartTime': 1770357441741263008,
#    'processorId': 10,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 56,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1690,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1635754555,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 178},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/var/run/docker.raw.sock'}}]}},
#  {'index': 21,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361152761242163,
#    'threadStartTime': 1770357441750829188,
#    'processorId': 6,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 67,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1701,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1762651660,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 190},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/var/run/docker.raw.sock'}}]}},
#  {'index': 22,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361152778435529,
#    'threadStartTime': 1770357441741263008,
#    'processorId': 14,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 56,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1690,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1635754555,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 190},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/var/run/docker.raw.sock'}}]}},
#  {'index': 23,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361154853742079,
#    'threadStartTime': 1770357442077217672,
#    'processorId': 4,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 104,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1757,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3211254034,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 125},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/run/guest-services/stats.sock'}}]}},
#  {'index': 24,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361154853798534,
#    'threadStartTime': 1770357441751507167,
#    'processorId': 13,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 69,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1703,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3613075782,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 178},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/run/guest-services/stats.sock'}}]}},
#  {'index': 25,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361155761411052,
#    'threadStartTime': 1770358094407525897,
#    'processorId': 16,
#    'processId': 909,
#    'cgroupId': 1,
#    'threadId': 909,
#    'parentProcessId': 908,
#    'hostProcessId': 2368,
#    'hostThreadId': 2368,
#    'hostParentProcessId': 2367,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 878587218,
#    'processEntityId': 878587218,
#    'parentEntityId': 1102894544,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1086},
#     {'name': 'pgid', 'type': 'int32', 'value': 1086}]}},
#  {'index': 26,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361155761493254,
#    'threadStartTime': 1770361155761339728,
#    'processorId': 1,
#    'processId': 1086,
#    'cgroupId': 1,
#    'threadId': 1086,
#    'parentProcessId': 909,
#    'hostProcessId': 2907,
#    'hostThreadId': 2907,
#    'hostParentProcessId': 2368,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 41223121,
#    'processEntityId': 41223121,
#    'parentEntityId': 878587218,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1086},
#     {'name': 'pgid', 'type': 'int32', 'value': 1086}]}},
#  {'index': 27,
#   'cluster_id': 3,
#   'data': {'timestamp': 1770361155762410217,
#    'threadStartTime': 1770361155761339728,
#    'processorId': 1,
#    'processId': 1086,
#    'cgroupId': 1,
#    'threadId': 1086,
#    'parentProcessId': 909,
#    'hostProcessId': 2907,
#    'hostThreadId': 2907,
#    'hostParentProcessId': 2368,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'ls',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '715',
#    'eventName': 'sched_process_exec',
#    'matchedPolicies': [''],
#    'argsNum': 17,
#    'returnValue': 0,
#    'syscall': 'execve',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 41223121,
#    'processEntityId': 41223121,
#    'parentEntityId': 878587218,
#    'args': [{'name': 'cmdpath', 'type': 'string', 'value': '/usr/bin/ls'},
#     {'name': 'pathname', 'type': 'string', 'value': '/usr/bin/ls'},
#     {'name': 'dev', 'type': 'uint32', 'value': 8388656},
#     {'name': 'inode', 'type': 'uint64', 'value': 1793},
#     {'name': 'ctime', 'type': 'uint64', 'value': 1770355888840991152},
#     {'name': 'inode_mode', 'type': 'uint16', 'value': 33261},
#     {'name': 'interpreter_pathname',
#      'type': 'string',
#      'value': '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'},
#     {'name': 'interpreter_dev', 'type': 'uint32', 'value': 8388656},
#     {'name': 'interpreter_inode', 'type': 'uint64', 'value': 11429},
#     {'name': 'interpreter_ctime',
#      'type': 'uint64',
#      'value': 1770355894092991029},
#     {'name': 'argv', 'type': '[]string', 'value': ['ls', '--color=auto']},
#     {'name': 'interp', 'type': 'string', 'value': '/usr/bin/ls'},
#     {'name': 'stdin_type', 'type': 'uint16', 'value': 8192},
#     {'name': 'stdin_path', 'type': 'string', 'value': '/dev/pts/7'},
#     {'name': 'invoked_from_kernel', 'type': 'bool', 'value': False},
#     {'name': 'prev_comm', 'type': 'string', 'value': 'bash'},
#     {'name': 'env', 'type': '[]string', 'value': []},
#     {'name': 'pwd', 'type': 'string', 'value': '/root'}]}},
#  {'index': 28,
#   'cluster_id': 9,
#   'data': {'timestamp': 1770361158290702504,
#    'threadStartTime': 1770358094407525897,
#    'processorId': 16,
#    'processId': 909,
#    'cgroupId': 1,
#    'threadId': 909,
#    'parentProcessId': 908,
#    'hostProcessId': 2368,
#    'hostThreadId': 2368,
#    'hostParentProcessId': 2367,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '92',
#    'eventName': 'chown',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'chown',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 878587218,
#    'processEntityId': 878587218,
#    'parentEntityId': 1102894544,
#    'args': [{'name': 'pathname',
#      'type': 'string',
#      'value': '/root/.bash_history'},
#     {'name': 'owner', 'type': 'int32', 'value': 0},
#     {'name': 'group', 'type': 'int32', 'value': 0}]}},
#  {'index': 29,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361158290805993,
#    'threadStartTime': 1770358094407525897,
#    'processorId': 16,
#    'processId': 909,
#    'cgroupId': 1,
#    'threadId': 909,
#    'parentProcessId': 908,
#    'hostProcessId': 2368,
#    'hostThreadId': 2368,
#    'hostParentProcessId': 2367,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 878587218,
#    'processEntityId': 878587218,
#    'parentEntityId': 1102894544,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 0},
#     {'name': 'pgid', 'type': 'int32', 'value': 909}]}},
#  {'index': 30,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361159404787784,
#    'threadStartTime': 1770358074887794790,
#    'processorId': 16,
#    'processId': 883,
#    'cgroupId': 1,
#    'threadId': 883,
#    'parentProcessId': 876,
#    'hostProcessId': 2341,
#    'hostThreadId': 2341,
#    'hostParentProcessId': 2334,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 2958871019,
#    'processEntityId': 2958871019,
#    'parentEntityId': 1753128393,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1087},
#     {'name': 'pgid', 'type': 'int32', 'value': 1087}]}},
#  {'index': 31,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361159407053814,
#    'threadStartTime': 1770361159404543900,
#    'processorId': 0,
#    'processId': 1087,
#    'cgroupId': 1,
#    'threadId': 1087,
#    'parentProcessId': 883,
#    'hostProcessId': 2908,
#    'hostThreadId': 2908,
#    'hostParentProcessId': 2341,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 2918335750,
#    'processEntityId': 2918335750,
#    'parentEntityId': 2958871019,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1087},
#     {'name': 'pgid', 'type': 'int32', 'value': 1087}]}},
#  {'index': 32,
#   'cluster_id': 3,
#   'data': {'timestamp': 1770361159407386112,
#    'threadStartTime': 1770361159404543900,
#    'processorId': 0,
#    'processId': 1087,
#    'cgroupId': 1,
#    'threadId': 1087,
#    'parentProcessId': 883,
#    'hostProcessId': 2908,
#    'hostThreadId': 2908,
#    'hostParentProcessId': 2341,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'ls',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '715',
#    'eventName': 'sched_process_exec',
#    'matchedPolicies': [''],
#    'argsNum': 17,
#    'returnValue': 0,
#    'syscall': 'execve',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 2918335750,
#    'processEntityId': 2918335750,
#    'parentEntityId': 2958871019,
#    'args': [{'name': 'cmdpath', 'type': 'string', 'value': '/usr/bin/ls'},
#     {'name': 'pathname', 'type': 'string', 'value': '/usr/bin/ls'},
#     {'name': 'dev', 'type': 'uint32', 'value': 8388656},
#     {'name': 'inode', 'type': 'uint64', 'value': 1793},
#     {'name': 'ctime', 'type': 'uint64', 'value': 1770355888840991152},
#     {'name': 'inode_mode', 'type': 'uint16', 'value': 33261},
#     {'name': 'interpreter_pathname',
#      'type': 'string',
#      'value': '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'},
#     {'name': 'interpreter_dev', 'type': 'uint32', 'value': 8388656},
#     {'name': 'interpreter_inode', 'type': 'uint64', 'value': 11429},
#     {'name': 'interpreter_ctime',
#      'type': 'uint64',
#      'value': 1770355894092991029},
#     {'name': 'argv', 'type': '[]string', 'value': ['ls', '--color=auto']},
#     {'name': 'interp', 'type': 'string', 'value': '/usr/bin/ls'},
#     {'name': 'stdin_type', 'type': 'uint16', 'value': 8192},
#     {'name': 'stdin_path', 'type': 'string', 'value': '/dev/pts/6'},
#     {'name': 'invoked_from_kernel', 'type': 'bool', 'value': False},
#     {'name': 'prev_comm', 'type': 'string', 'value': 'bash'},
#     {'name': 'env', 'type': '[]string', 'value': []},
#     {'name': 'pwd', 'type': 'string', 'value': '/home/sylee'}]}},
#  {'index': 33,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361159436768460,
#    'threadStartTime': 1770357441741888323,
#    'processorId': 2,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 59,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1693,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1548783990,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 125},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/run/guest-services/stats.sock'}}]}},
#  {'index': 34,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361160606423637,
#    'threadStartTime': 1770358074887794790,
#    'processorId': 16,
#    'processId': 883,
#    'cgroupId': 1,
#    'threadId': 883,
#    'parentProcessId': 876,
#    'hostProcessId': 2341,
#    'hostThreadId': 2341,
#    'hostParentProcessId': 2334,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 2958871019,
#    'processEntityId': 2958871019,
#    'parentEntityId': 1753128393,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1088},
#     {'name': 'pgid', 'type': 'int32', 'value': 883}]}},
#  {'index': 35,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361160606500187,
#    'threadStartTime': 1770361160606361143,
#    'processorId': 2,
#    'processId': 1088,
#    'cgroupId': 1,
#    'threadId': 1088,
#    'parentProcessId': 883,
#    'hostProcessId': 2909,
#    'hostThreadId': 2909,
#    'hostParentProcessId': 2341,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 823981424,
#    'processEntityId': 823981424,
#    'parentEntityId': 2958871019,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1088},
#     {'name': 'pgid', 'type': 'int32', 'value': 883}]}},
#  {'index': 36,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361160607236350,
#    'threadStartTime': 1770358074887794790,
#    'processorId': 16,
#    'processId': 883,
#    'cgroupId': 1,
#    'threadId': 883,
#    'parentProcessId': 876,
#    'hostProcessId': 2341,
#    'hostThreadId': 2341,
#    'hostParentProcessId': 2334,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 2958871019,
#    'processEntityId': 2958871019,
#    'parentEntityId': 1753128393,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1089},
#     {'name': 'pgid', 'type': 'int32', 'value': 883}]}},
#  {'index': 37,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361160607402045,
#    'threadStartTime': 1770361160607159490,
#    'processorId': 5,
#    'processId': 1089,
#    'cgroupId': 1,
#    'threadId': 1089,
#    'parentProcessId': 883,
#    'hostProcessId': 2910,
#    'hostThreadId': 2910,
#    'hostParentProcessId': 2341,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3200155063,
#    'processEntityId': 3200155063,
#    'parentEntityId': 2958871019,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1089},
#     {'name': 'pgid', 'type': 'int32', 'value': 883}]}},
#  {'index': 38,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361161122541318,
#    'threadStartTime': 1770358074887794790,
#    'processorId': 16,
#    'processId': 883,
#    'cgroupId': 1,
#    'threadId': 883,
#    'parentProcessId': 876,
#    'hostProcessId': 2341,
#    'hostThreadId': 2341,
#    'hostParentProcessId': 2334,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 2958871019,
#    'processEntityId': 2958871019,
#    'parentEntityId': 1753128393,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1090},
#     {'name': 'pgid', 'type': 'int32', 'value': 1090}]}},
#  {'index': 39,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361161122598747,
#    'threadStartTime': 1770361161122374995,
#    'processorId': 0,
#    'processId': 1090,
#    'cgroupId': 1,
#    'threadId': 1090,
#    'parentProcessId': 883,
#    'hostProcessId': 2911,
#    'hostThreadId': 2911,
#    'hostParentProcessId': 2341,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 2835044789,
# ...
#    'syscall': 'setresgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'rgid', 'type': 'int32', 'value': -1},
#     {'name': 'egid', 'type': 'int32', 'value': 1000},
#     {'name': 'sgid', 'type': 'int32', 'value': -1}]}},
#  {'index': 706,
#   'cluster_id': 6,
#   'data': {'timestamp': 1770361222491829993,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '117',
#    'eventName': 'setresuid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresuid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'ruid', 'type': 'int32', 'value': -1},
#     {'name': 'euid', 'type': 'int32', 'value': 1000},
#     {'name': 'suid', 'type': 'int32', 'value': -1}]}},
#  {'index': 707,
#   'cluster_id': 6,
#   'data': {'timestamp': 1770361222491884249,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '117',
#    'eventName': 'setresuid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresuid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'ruid', 'type': 'int32', 'value': -1},
#     {'name': 'euid', 'type': 'int32', 'value': 0},
#     {'name': 'suid', 'type': 'int32', 'value': -1}]}},
#  {'index': 708,
#   'cluster_id': 5,
#   'data': {'timestamp': 1770361222491893797,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '119',
#    'eventName': 'setresgid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'rgid', 'type': 'int32', 'value': -1},
#     {'name': 'egid', 'type': 'int32', 'value': 0},
#     {'name': 'sgid', 'type': 'int32', 'value': -1}]}},
#  {'index': 709,
#   'cluster_id': 5,
#   'data': {'timestamp': 1770361222492109173,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 16,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '119',
#    'eventName': 'setresgid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'rgid', 'type': 'int32', 'value': -1},
#     {'name': 'egid', 'type': 'int32', 'value': 1000},
#     {'name': 'sgid', 'type': 'int32', 'value': -1}]}},
#  {'index': 710,
#   'cluster_id': 6,
#   'data': {'timestamp': 1770361222492155101,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 16,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '117',
#    'eventName': 'setresuid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresuid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'ruid', 'type': 'int32', 'value': -1},
#     {'name': 'euid', 'type': 'int32', 'value': 1000},
#     {'name': 'suid', 'type': 'int32', 'value': -1}]}},
#  {'index': 711,
#   'cluster_id': 6,
#   'data': {'timestamp': 1770361222492165370,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 16,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '117',
#    'eventName': 'setresuid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresuid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'ruid', 'type': 'int32', 'value': -1},
#     {'name': 'euid', 'type': 'int32', 'value': 0},
#     {'name': 'suid', 'type': 'int32', 'value': -1}]}},
#  {'index': 712,
#   'cluster_id': 5,
#   'data': {'timestamp': 1770361222492179368,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 16,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '119',
#    'eventName': 'setresgid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'rgid', 'type': 'int32', 'value': -1},
#     {'name': 'egid', 'type': 'int32', 'value': 0},
#     {'name': 'sgid', 'type': 'int32', 'value': -1}]}},
#  {'index': 713,
#   'cluster_id': 5,
#   'data': {'timestamp': 1770361222492767672,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '119',
#    'eventName': 'setresgid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'rgid', 'type': 'int32', 'value': -1},
#     {'name': 'egid', 'type': 'int32', 'value': 1000},
#     {'name': 'sgid', 'type': 'int32', 'value': -1}]}},
#  {'index': 714,
#   'cluster_id': 6,
#   'data': {'timestamp': 1770361222492801980,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '117',
#    'eventName': 'setresuid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresuid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'ruid', 'type': 'int32', 'value': -1},
#     {'name': 'euid', 'type': 'int32', 'value': 1000},
#     {'name': 'suid', 'type': 'int32', 'value': -1}]}},
#  {'index': 715,
#   'cluster_id': 6,
#   'data': {'timestamp': 1770361222492821364,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '117',
#    'eventName': 'setresuid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresuid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'ruid', 'type': 'int32', 'value': -1},
#     {'name': 'euid', 'type': 'int32', 'value': 0},
#     {'name': 'suid', 'type': 'int32', 'value': -1}]}},
#  {'index': 716,
#   'cluster_id': 5,
#   'data': {'timestamp': 1770361222492825501,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '119',
#    'eventName': 'setresgid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'rgid', 'type': 'int32', 'value': -1},
#     {'name': 'egid', 'type': 'int32', 'value': 0},
#     {'name': 'sgid', 'type': 'int32', 'value': -1}]}},
#  {'index': 717,
#   'cluster_id': 5,
#   'data': {'timestamp': 1770361222492999882,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '119',
#    'eventName': 'setresgid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'rgid', 'type': 'int32', 'value': -1},
#     {'name': 'egid', 'type': 'int32', 'value': 1000},
#     {'name': 'sgid', 'type': 'int32', 'value': -1}]}},
#  {'index': 718,
#   'cluster_id': 6,
#   'data': {'timestamp': 1770361222493038442,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '117',
#    'eventName': 'setresuid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresuid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'ruid', 'type': 'int32', 'value': -1},
#     {'name': 'euid', 'type': 'int32', 'value': 1000},
#     {'name': 'suid', 'type': 'int32', 'value': -1}]}},
#  {'index': 719,
#   'cluster_id': 6,
#   'data': {'timestamp': 1770361222493058480,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '117',
#    'eventName': 'setresuid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresuid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'ruid', 'type': 'int32', 'value': -1},
#     {'name': 'euid', 'type': 'int32', 'value': 0},
#     {'name': 'suid', 'type': 'int32', 'value': -1}]}},
#  {'index': 720,
#   'cluster_id': 5,
#   'data': {'timestamp': 1770361222493064427,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '119',
#    'eventName': 'setresgid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'rgid', 'type': 'int32', 'value': -1},
#     {'name': 'egid', 'type': 'int32', 'value': 0},
#     {'name': 'sgid', 'type': 'int32', 'value': -1}]}}]

# %%
matched_sequence
# Out:
# [{'index': 0,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361145686246159,
#    'threadStartTime': 1770357810525966063,
#    'processorId': 9,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 365,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 2164,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1496401534,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 178},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/run/guest-services/stats.sock'}}]}},
#  {'index': 1,
#   'cluster_id': 7,
#   'data': {'timestamp': 1770361145837665844,
#    'threadStartTime': 1770361143499520647,
#    'processorId': 5,
#    'processId': 800,
#    'cgroupId': 3488,
#    'threadId': 803,
#    'parentProcessId': 786,
#    'hostProcessId': 2882,
#    'hostThreadId': 2885,
#    'hostParentProcessId': 2868,
#    'userId': 0,
#    'mountNamespace': 4026532315,
#    'pidNamespace': 4026532391,
#    'processName': 'tracee',
#    'executable': {'path': ''},
#    'hostName': '6e299da3f233',
#    'containerId': '6e299da3f233b5254d582293312a8999470f164e3933c4ea2b56b4a622e2616a',
#    'container': {'id': '6e299da3f233b5254d582293312a8999470f164e3933c4ea2b56b4a622e2616a',
#     'name': 'tracee_1',
#     'image': 'aquasec/tracee:latest',
#     'imageDigest': 'aquasec/tracee@sha256:cfbbfee972e64a644f6b1bac74ee26998e6e12442697be4c797ae563553a2a5b'},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': True, 'isCompat': False},
#    'threadEntityId': 478529230,
#    'processEntityId': 2693343887,
#    'parentEntityId': 1159042132,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 393},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX', 'sun_path': '/var/run/docker.sock'}}]}},
#  {'index': 2,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145838839570,
#    'threadStartTime': 1770357444963927576,
#    'processorId': 12,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 798,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2073,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3442353639,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 3,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145841368018,
#    'threadStartTime': 1770357444969382056,
#    'processorId': 6,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 801,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2076,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 43146251,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 4,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145845710829,
#    'threadStartTime': 1770357444918185943,
#    'processorId': 10,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 796,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2071,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 428122265,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/guest-services/docker.proxy.sock'}}]}},
#  {'index': 5,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361145846198606,
#    'threadStartTime': 1770357810525966063,
#    'processorId': 12,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 365,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 2164,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1496401534,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 200},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/var/run/docker.raw.sock'}}]}},
#  {'index': 6,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145847737838,
#    'threadStartTime': 1770357444969382056,
#    'processorId': 6,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 801,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2076,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 43146251,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 7,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145850720676,
#    'threadStartTime': 1770357444964082790,
#    'processorId': 7,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 799,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2074,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1048328759,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 8,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145852813054,
#    'threadStartTime': 1770357444964082790,
#    'processorId': 7,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 799,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2074,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1048328759,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 9,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145855624625,
#    'threadStartTime': 1770357444918185943,
#    'processorId': 10,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 796,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2071,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 428122265,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/guest-services/docker.proxy.sock'}}]}},
#  {'index': 10,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361145856127453,
#    'threadStartTime': 1770357441751507167,
#    'processorId': 15,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 69,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1703,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3613075782,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 190},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/var/run/docker.raw.sock'}}]}},
#  {'index': 11,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145860083439,
#    'threadStartTime': 1770357444969382056,
#    'processorId': 6,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 801,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2076,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 43146251,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 12,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145863744372,
#    'threadStartTime': 1770357444964082790,
#    'processorId': 7,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 799,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2074,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1048328759,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 13,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145866833193,
#    'threadStartTime': 1770357444964082790,
#    'processorId': 10,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 799,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2074,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1048328759,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 14,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145869256436,
#    'threadStartTime': 1770357444918185943,
#    'processorId': 3,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 796,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2071,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 428122265,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/guest-services/docker.proxy.sock'}}]}},
#  {'index': 15,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361145869820917,
#    'threadStartTime': 1770357441741263008,
#    'processorId': 14,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 56,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1690,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1635754555,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 190},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/var/run/docker.raw.sock'}}]}},
#  {'index': 16,
#   'cluster_id': 1,
#   'data': {'timestamp': 1770361145912806485,
#    'threadStartTime': 1770357444963927576,
#    'processorId': 4,
#    'processId': 791,
#    'cgroupId': 1,
#    'threadId': 798,
#    'parentProcessId': 790,
#    'hostProcessId': 2066,
#    'hostThreadId': 2073,
#    'hostParentProcessId': 2065,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'docker-desktop-',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3442353639,
#    'processEntityId': 1873843225,
#    'parentEntityId': 4272832523,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 21},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/mnt/wsl/docker-desktop/shared-sockets/host-services/backend.sock'}}]}},
#  {'index': 17,
#   'cluster_id': 8,
#   'data': {'timestamp': 1770361145837665844,
#    'threadStartTime': 1770361143499520647,
#    'processorId': 5,
#    'processId': 800,
#    'cgroupId': 3488,
#    'threadId': 803,
#    'parentProcessId': 786,
#    'hostProcessId': 2882,
#    'hostThreadId': 2885,
#    'hostParentProcessId': 2868,
#    'userId': 0,
#    'mountNamespace': 4026532315,
#    'pidNamespace': 4026532391,
#    'processName': 'tracee',
#    'executable': {'path': ''},
#    'hostName': '6e299da3f233',
#    'containerId': '6e299da3f233b5254d582293312a8999470f164e3933c4ea2b56b4a622e2616a',
#    'container': {'id': '6e299da3f233b5254d582293312a8999470f164e3933c4ea2b56b4a622e2616a',
#     'name': 'tracee_1',
#     'image': 'aquasec/tracee:latest',
#     'imageDigest': 'aquasec/tracee@sha256:cfbbfee972e64a644f6b1bac74ee26998e6e12442697be4c797ae563553a2a5b'},
#    'kubernetes': {},
#    'eventId': '6004',
#    'eventName': 'docker_abuse',
#    'matchedPolicies': [''],
#    'argsNum': 1,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': True, 'isCompat': False},
#    'threadEntityId': 478529230,
#    'processEntityId': 2693343887,
#    'parentEntityId': 1159042132,
#    'args': [{'name': 'detectedFrom',
#      'type': 'unknown',
#      'value': {'args': [{'name': 'sockfd', 'type': 'int32', 'value': 393},
#        {'name': 'type', 'type': 'int32', 'value': 1},
#        {'name': 'remote_addr',
#         'type': 'SockAddr',
#         'value': {'sa_family': 'AF_UNIX',
#          'sun_path': '/var/run/docker.sock'}}],
#       'id': 736,
#       'name': 'security_socket_connect',
#       'returnValue': 0}}],
#    'metadata': {'Version': '1',
#     'Description': 'An attempt to abuse the Docker UNIX socket inside a container was detected. docker.sock is the UNIX socket that Docker uses as the entry point to the Docker API. Adversaries may attempt to abuse this socket to compromise the system.',
#     'Tags': None,
#     'Properties': {'Category': 'privilege-escalation',
#      'Kubernetes_Technique': '',
#      'Severity': 2,
#      'Technique': 'Exploitation for Privilege Escalation',
#      'external_id': 'T1068',
#      'id': 'attack-pattern--b21c3b2d-02e6-45b1-980b-e69051040839',
#      'signatureID': 'TRC-1019',
#      'signatureName': 'Docker socket abuse detected'}}}},
#  {'index': 18,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361150270108776,
#    'threadStartTime': 1770357441751507167,
#    'processorId': 13,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 69,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1703,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3613075782,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 178},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/run/guest-services/stats.sock'}}]}},
#  {'index': 19,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361152752993617,
#    'threadStartTime': 1770357441750829188,
#    'processorId': 10,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 67,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1701,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1762651660,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 178},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/var/run/docker.raw.sock'}}]}},
#  {'index': 20,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361152757078372,
#    'threadStartTime': 1770357441741263008,
#    'processorId': 10,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 56,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1690,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1635754555,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 178},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/var/run/docker.raw.sock'}}]}},
#  {'index': 21,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361152761242163,
#    'threadStartTime': 1770357441750829188,
#    'processorId': 6,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 67,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1701,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1762651660,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 190},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/var/run/docker.raw.sock'}}]}},
#  {'index': 22,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361152778435529,
#    'threadStartTime': 1770357441741263008,
#    'processorId': 14,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 56,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1690,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1635754555,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 190},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/var/run/docker.raw.sock'}}]}},
#  {'index': 23,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361154853742079,
#    'threadStartTime': 1770357442077217672,
#    'processorId': 4,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 104,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1757,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3211254034,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 125},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/run/guest-services/stats.sock'}}]}},
#  {'index': 24,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361154853798534,
#    'threadStartTime': 1770357441751507167,
#    'processorId': 13,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 69,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1703,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3613075782,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 178},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/run/guest-services/stats.sock'}}]}},
#  {'index': 25,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361155761411052,
#    'threadStartTime': 1770358094407525897,
#    'processorId': 16,
#    'processId': 909,
#    'cgroupId': 1,
#    'threadId': 909,
#    'parentProcessId': 908,
#    'hostProcessId': 2368,
#    'hostThreadId': 2368,
#    'hostParentProcessId': 2367,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 878587218,
#    'processEntityId': 878587218,
#    'parentEntityId': 1102894544,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1086},
#     {'name': 'pgid', 'type': 'int32', 'value': 1086}]}},
#  {'index': 26,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361155761493254,
#    'threadStartTime': 1770361155761339728,
#    'processorId': 1,
#    'processId': 1086,
#    'cgroupId': 1,
#    'threadId': 1086,
#    'parentProcessId': 909,
#    'hostProcessId': 2907,
#    'hostThreadId': 2907,
#    'hostParentProcessId': 2368,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 41223121,
#    'processEntityId': 41223121,
#    'parentEntityId': 878587218,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1086},
#     {'name': 'pgid', 'type': 'int32', 'value': 1086}]}},
#  {'index': 27,
#   'cluster_id': 3,
#   'data': {'timestamp': 1770361155762410217,
#    'threadStartTime': 1770361155761339728,
#    'processorId': 1,
#    'processId': 1086,
#    'cgroupId': 1,
#    'threadId': 1086,
#    'parentProcessId': 909,
#    'hostProcessId': 2907,
#    'hostThreadId': 2907,
#    'hostParentProcessId': 2368,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'ls',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '715',
#    'eventName': 'sched_process_exec',
#    'matchedPolicies': [''],
#    'argsNum': 17,
#    'returnValue': 0,
#    'syscall': 'execve',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 41223121,
#    'processEntityId': 41223121,
#    'parentEntityId': 878587218,
#    'args': [{'name': 'cmdpath', 'type': 'string', 'value': '/usr/bin/ls'},
#     {'name': 'pathname', 'type': 'string', 'value': '/usr/bin/ls'},
#     {'name': 'dev', 'type': 'uint32', 'value': 8388656},
#     {'name': 'inode', 'type': 'uint64', 'value': 1793},
#     {'name': 'ctime', 'type': 'uint64', 'value': 1770355888840991152},
#     {'name': 'inode_mode', 'type': 'uint16', 'value': 33261},
#     {'name': 'interpreter_pathname',
#      'type': 'string',
#      'value': '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'},
#     {'name': 'interpreter_dev', 'type': 'uint32', 'value': 8388656},
#     {'name': 'interpreter_inode', 'type': 'uint64', 'value': 11429},
#     {'name': 'interpreter_ctime',
#      'type': 'uint64',
#      'value': 1770355894092991029},
#     {'name': 'argv', 'type': '[]string', 'value': ['ls', '--color=auto']},
#     {'name': 'interp', 'type': 'string', 'value': '/usr/bin/ls'},
#     {'name': 'stdin_type', 'type': 'uint16', 'value': 8192},
#     {'name': 'stdin_path', 'type': 'string', 'value': '/dev/pts/7'},
#     {'name': 'invoked_from_kernel', 'type': 'bool', 'value': False},
#     {'name': 'prev_comm', 'type': 'string', 'value': 'bash'},
#     {'name': 'env', 'type': '[]string', 'value': []},
#     {'name': 'pwd', 'type': 'string', 'value': '/root'}]}},
#  {'index': 28,
#   'cluster_id': 9,
#   'data': {'timestamp': 1770361158290702504,
#    'threadStartTime': 1770358094407525897,
#    'processorId': 16,
#    'processId': 909,
#    'cgroupId': 1,
#    'threadId': 909,
#    'parentProcessId': 908,
#    'hostProcessId': 2368,
#    'hostThreadId': 2368,
#    'hostParentProcessId': 2367,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '92',
#    'eventName': 'chown',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'chown',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 878587218,
#    'processEntityId': 878587218,
#    'parentEntityId': 1102894544,
#    'args': [{'name': 'pathname',
#      'type': 'string',
#      'value': '/root/.bash_history'},
#     {'name': 'owner', 'type': 'int32', 'value': 0},
#     {'name': 'group', 'type': 'int32', 'value': 0}]}},
#  {'index': 29,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361158290805993,
#    'threadStartTime': 1770358094407525897,
#    'processorId': 16,
#    'processId': 909,
#    'cgroupId': 1,
#    'threadId': 909,
#    'parentProcessId': 908,
#    'hostProcessId': 2368,
#    'hostThreadId': 2368,
#    'hostParentProcessId': 2367,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 878587218,
#    'processEntityId': 878587218,
#    'parentEntityId': 1102894544,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 0},
#     {'name': 'pgid', 'type': 'int32', 'value': 909}]}},
#  {'index': 30,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361159404787784,
#    'threadStartTime': 1770358074887794790,
#    'processorId': 16,
#    'processId': 883,
#    'cgroupId': 1,
#    'threadId': 883,
#    'parentProcessId': 876,
#    'hostProcessId': 2341,
#    'hostThreadId': 2341,
#    'hostParentProcessId': 2334,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 2958871019,
#    'processEntityId': 2958871019,
#    'parentEntityId': 1753128393,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1087},
#     {'name': 'pgid', 'type': 'int32', 'value': 1087}]}},
#  {'index': 31,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361159407053814,
#    'threadStartTime': 1770361159404543900,
#    'processorId': 0,
#    'processId': 1087,
#    'cgroupId': 1,
#    'threadId': 1087,
#    'parentProcessId': 883,
#    'hostProcessId': 2908,
#    'hostThreadId': 2908,
#    'hostParentProcessId': 2341,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 2918335750,
#    'processEntityId': 2918335750,
#    'parentEntityId': 2958871019,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1087},
#     {'name': 'pgid', 'type': 'int32', 'value': 1087}]}},
#  {'index': 32,
#   'cluster_id': 3,
#   'data': {'timestamp': 1770361159407386112,
#    'threadStartTime': 1770361159404543900,
#    'processorId': 0,
#    'processId': 1087,
#    'cgroupId': 1,
#    'threadId': 1087,
#    'parentProcessId': 883,
#    'hostProcessId': 2908,
#    'hostThreadId': 2908,
#    'hostParentProcessId': 2341,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'ls',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '715',
#    'eventName': 'sched_process_exec',
#    'matchedPolicies': [''],
#    'argsNum': 17,
#    'returnValue': 0,
#    'syscall': 'execve',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 2918335750,
#    'processEntityId': 2918335750,
#    'parentEntityId': 2958871019,
#    'args': [{'name': 'cmdpath', 'type': 'string', 'value': '/usr/bin/ls'},
#     {'name': 'pathname', 'type': 'string', 'value': '/usr/bin/ls'},
#     {'name': 'dev', 'type': 'uint32', 'value': 8388656},
#     {'name': 'inode', 'type': 'uint64', 'value': 1793},
#     {'name': 'ctime', 'type': 'uint64', 'value': 1770355888840991152},
#     {'name': 'inode_mode', 'type': 'uint16', 'value': 33261},
#     {'name': 'interpreter_pathname',
#      'type': 'string',
#      'value': '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'},
#     {'name': 'interpreter_dev', 'type': 'uint32', 'value': 8388656},
#     {'name': 'interpreter_inode', 'type': 'uint64', 'value': 11429},
#     {'name': 'interpreter_ctime',
#      'type': 'uint64',
#      'value': 1770355894092991029},
#     {'name': 'argv', 'type': '[]string', 'value': ['ls', '--color=auto']},
#     {'name': 'interp', 'type': 'string', 'value': '/usr/bin/ls'},
#     {'name': 'stdin_type', 'type': 'uint16', 'value': 8192},
#     {'name': 'stdin_path', 'type': 'string', 'value': '/dev/pts/6'},
#     {'name': 'invoked_from_kernel', 'type': 'bool', 'value': False},
#     {'name': 'prev_comm', 'type': 'string', 'value': 'bash'},
#     {'name': 'env', 'type': '[]string', 'value': []},
#     {'name': 'pwd', 'type': 'string', 'value': '/home/sylee'}]}},
#  {'index': 33,
#   'cluster_id': 0,
#   'data': {'timestamp': 1770361159436768460,
#    'threadStartTime': 1770357441741888323,
#    'processorId': 2,
#    'processId': 21,
#    'cgroupId': 1,
#    'threadId': 59,
#    'parentProcessId': 1,
#    'hostProcessId': 1632,
#    'hostThreadId': 1693,
#    'hostParentProcessId': 1612,
#    'userId': 0,
#    'mountNamespace': 4026532390,
#    'pidNamespace': 4026532391,
#    'processName': 'initd',
#    'executable': {'path': ''},
#    'hostName': 'docker-desktop',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '736',
#    'eventName': 'security_socket_connect',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'connect',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 1548783990,
#    'processEntityId': 2522573051,
#    'parentEntityId': 463719362,
#    'args': [{'name': 'sockfd', 'type': 'int32', 'value': 125},
#     {'name': 'type', 'type': 'int32', 'value': 1},
#     {'name': 'remote_addr',
#      'type': 'SockAddr',
#      'value': {'sa_family': 'AF_UNIX',
#       'sun_path': '/run/guest-services/stats.sock'}}]}},
#  {'index': 34,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361160606423637,
#    'threadStartTime': 1770358074887794790,
#    'processorId': 16,
#    'processId': 883,
#    'cgroupId': 1,
#    'threadId': 883,
#    'parentProcessId': 876,
#    'hostProcessId': 2341,
#    'hostThreadId': 2341,
#    'hostParentProcessId': 2334,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 2958871019,
#    'processEntityId': 2958871019,
#    'parentEntityId': 1753128393,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1088},
#     {'name': 'pgid', 'type': 'int32', 'value': 883}]}},
#  {'index': 35,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361160606500187,
#    'threadStartTime': 1770361160606361143,
#    'processorId': 2,
#    'processId': 1088,
#    'cgroupId': 1,
#    'threadId': 1088,
#    'parentProcessId': 883,
#    'hostProcessId': 2909,
#    'hostThreadId': 2909,
#    'hostParentProcessId': 2341,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 823981424,
#    'processEntityId': 823981424,
#    'parentEntityId': 2958871019,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1088},
#     {'name': 'pgid', 'type': 'int32', 'value': 883}]}},
#  {'index': 36,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361160607236350,
#    'threadStartTime': 1770358074887794790,
#    'processorId': 16,
#    'processId': 883,
#    'cgroupId': 1,
#    'threadId': 883,
#    'parentProcessId': 876,
#    'hostProcessId': 2341,
#    'hostThreadId': 2341,
#    'hostParentProcessId': 2334,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 2958871019,
#    'processEntityId': 2958871019,
#    'parentEntityId': 1753128393,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1089},
#     {'name': 'pgid', 'type': 'int32', 'value': 883}]}},
#  {'index': 37,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361160607402045,
#    'threadStartTime': 1770361160607159490,
#    'processorId': 5,
#    'processId': 1089,
#    'cgroupId': 1,
#    'threadId': 1089,
#    'parentProcessId': 883,
#    'hostProcessId': 2910,
#    'hostThreadId': 2910,
#    'hostParentProcessId': 2341,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3200155063,
#    'processEntityId': 3200155063,
#    'parentEntityId': 2958871019,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1089},
#     {'name': 'pgid', 'type': 'int32', 'value': 883}]}},
#  {'index': 38,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361161122541318,
#    'threadStartTime': 1770358074887794790,
#    'processorId': 16,
#    'processId': 883,
#    'cgroupId': 1,
#    'threadId': 883,
#    'parentProcessId': 876,
#    'hostProcessId': 2341,
#    'hostThreadId': 2341,
#    'hostParentProcessId': 2334,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 2958871019,
#    'processEntityId': 2958871019,
#    'parentEntityId': 1753128393,
#    'args': [{'name': 'pid', 'type': 'int32', 'value': 1090},
#     {'name': 'pgid', 'type': 'int32', 'value': 1090}]}},
#  {'index': 39,
#   'cluster_id': 2,
#   'data': {'timestamp': 1770361161122598747,
#    'threadStartTime': 1770361161122374995,
#    'processorId': 0,
#    'processId': 1090,
#    'cgroupId': 1,
#    'threadId': 1090,
#    'parentProcessId': 883,
#    'hostProcessId': 2911,
#    'hostThreadId': 2911,
#    'hostParentProcessId': 2341,
#    'userId': 1000,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'bash',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '109',
#    'eventName': 'setpgid',
#    'matchedPolicies': [''],
#    'argsNum': 2,
#    'returnValue': 0,
#    'syscall': 'setpgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 2835044789,
# ...
#    'syscall': 'setresgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'rgid', 'type': 'int32', 'value': -1},
#     {'name': 'egid', 'type': 'int32', 'value': 1000},
#     {'name': 'sgid', 'type': 'int32', 'value': -1}]}},
#  {'index': 706,
#   'cluster_id': 6,
#   'data': {'timestamp': 1770361222491829993,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '117',
#    'eventName': 'setresuid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresuid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'ruid', 'type': 'int32', 'value': -1},
#     {'name': 'euid', 'type': 'int32', 'value': 1000},
#     {'name': 'suid', 'type': 'int32', 'value': -1}]}},
#  {'index': 707,
#   'cluster_id': 6,
#   'data': {'timestamp': 1770361222491884249,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '117',
#    'eventName': 'setresuid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresuid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'ruid', 'type': 'int32', 'value': -1},
#     {'name': 'euid', 'type': 'int32', 'value': 0},
#     {'name': 'suid', 'type': 'int32', 'value': -1}]}},
#  {'index': 708,
#   'cluster_id': 5,
#   'data': {'timestamp': 1770361222491893797,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '119',
#    'eventName': 'setresgid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'rgid', 'type': 'int32', 'value': -1},
#     {'name': 'egid', 'type': 'int32', 'value': 0},
#     {'name': 'sgid', 'type': 'int32', 'value': -1}]}},
#  {'index': 709,
#   'cluster_id': 5,
#   'data': {'timestamp': 1770361222492109173,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 16,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '119',
#    'eventName': 'setresgid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'rgid', 'type': 'int32', 'value': -1},
#     {'name': 'egid', 'type': 'int32', 'value': 1000},
#     {'name': 'sgid', 'type': 'int32', 'value': -1}]}},
#  {'index': 710,
#   'cluster_id': 6,
#   'data': {'timestamp': 1770361222492155101,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 16,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '117',
#    'eventName': 'setresuid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresuid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'ruid', 'type': 'int32', 'value': -1},
#     {'name': 'euid', 'type': 'int32', 'value': 1000},
#     {'name': 'suid', 'type': 'int32', 'value': -1}]}},
#  {'index': 711,
#   'cluster_id': 6,
#   'data': {'timestamp': 1770361222492165370,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 16,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '117',
#    'eventName': 'setresuid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresuid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'ruid', 'type': 'int32', 'value': -1},
#     {'name': 'euid', 'type': 'int32', 'value': 0},
#     {'name': 'suid', 'type': 'int32', 'value': -1}]}},
#  {'index': 712,
#   'cluster_id': 5,
#   'data': {'timestamp': 1770361222492179368,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 16,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '119',
#    'eventName': 'setresgid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'rgid', 'type': 'int32', 'value': -1},
#     {'name': 'egid', 'type': 'int32', 'value': 0},
#     {'name': 'sgid', 'type': 'int32', 'value': -1}]}},
#  {'index': 713,
#   'cluster_id': 5,
#   'data': {'timestamp': 1770361222492767672,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '119',
#    'eventName': 'setresgid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'rgid', 'type': 'int32', 'value': -1},
#     {'name': 'egid', 'type': 'int32', 'value': 1000},
#     {'name': 'sgid', 'type': 'int32', 'value': -1}]}},
#  {'index': 714,
#   'cluster_id': 6,
#   'data': {'timestamp': 1770361222492801980,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '117',
#    'eventName': 'setresuid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresuid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'ruid', 'type': 'int32', 'value': -1},
#     {'name': 'euid', 'type': 'int32', 'value': 1000},
#     {'name': 'suid', 'type': 'int32', 'value': -1}]}},
#  {'index': 715,
#   'cluster_id': 6,
#   'data': {'timestamp': 1770361222492821364,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '117',
#    'eventName': 'setresuid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresuid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'ruid', 'type': 'int32', 'value': -1},
#     {'name': 'euid', 'type': 'int32', 'value': 0},
#     {'name': 'suid', 'type': 'int32', 'value': -1}]}},
#  {'index': 716,
#   'cluster_id': 5,
#   'data': {'timestamp': 1770361222492825501,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '119',
#    'eventName': 'setresgid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'rgid', 'type': 'int32', 'value': -1},
#     {'name': 'egid', 'type': 'int32', 'value': 0},
#     {'name': 'sgid', 'type': 'int32', 'value': -1}]}},
#  {'index': 717,
#   'cluster_id': 5,
#   'data': {'timestamp': 1770361222492999882,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '119',
#    'eventName': 'setresgid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'rgid', 'type': 'int32', 'value': -1},
#     {'name': 'egid', 'type': 'int32', 'value': 1000},
#     {'name': 'sgid', 'type': 'int32', 'value': -1}]}},
#  {'index': 718,
#   'cluster_id': 6,
#   'data': {'timestamp': 1770361222493038442,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '117',
#    'eventName': 'setresuid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresuid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'ruid', 'type': 'int32', 'value': -1},
#     {'name': 'euid', 'type': 'int32', 'value': 1000},
#     {'name': 'suid', 'type': 'int32', 'value': -1}]}},
#  {'index': 719,
#   'cluster_id': 6,
#   'data': {'timestamp': 1770361222493058480,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '117',
#    'eventName': 'setresuid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresuid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'ruid', 'type': 'int32', 'value': -1},
#     {'name': 'euid', 'type': 'int32', 'value': 0},
#     {'name': 'suid', 'type': 'int32', 'value': -1}]}},
#  {'index': 720,
#   'cluster_id': 5,
#   'data': {'timestamp': 1770361222493064427,
#    'threadStartTime': 1770361222399978680,
#    'processorId': 8,
#    'processId': 6,
#    'cgroupId': 1,
#    'threadId': 1118,
#    'parentProcessId': 2,
#    'hostProcessId': 322,
#    'hostThreadId': 2947,
#    'hostParentProcessId': 297,
#    'userId': 0,
#    'mountNamespace': 4026532219,
#    'pidNamespace': 4026532221,
#    'processName': 'init',
#    'executable': {'path': ''},
#    'hostName': 'localhost',
#    'containerId': '',
#    'container': {},
#    'kubernetes': {},
#    'eventId': '119',
#    'eventName': 'setresgid',
#    'matchedPolicies': [''],
#    'argsNum': 3,
#    'returnValue': 0,
#    'syscall': 'setresgid',
#    'stackAddresses': None,
#    'contextFlags': {'containerStarted': False, 'isCompat': False},
#    'threadEntityId': 3710463741,
#    'processEntityId': 3787952947,
#    'parentEntityId': 3553632740,
#    'args': [{'name': 'rgid', 'type': 'int32', 'value': -1},
#     {'name': 'egid', 'type': 'int32', 'value': 0},
#     {'name': 'sgid', 'type': 'int32', 'value': -1}]}}]
